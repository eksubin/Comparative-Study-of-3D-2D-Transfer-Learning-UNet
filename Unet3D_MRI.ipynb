# %%
from monai.utils import first, set_determinism
from monai.transforms import (
    AsDiscrete,
    AsDiscreted,
    EnsureChannelFirstd,
    Compose,
    CropForegroundd,
    LoadImaged,
    Orientationd,
    RandCropByPosNegLabeld,
    SaveImaged,
    ScaleIntensityRanged,
    Spacingd,
    Invertd,
    Lambdad
)
from monai.handlers.utils import from_engine
from monai.networks.nets import UNet
from monai.networks.layers import Norm
from monai.metrics import DiceMetric
from monai.losses import DiceLoss
from monai.inferers import sliding_window_inference
from monai.data import CacheDataset, DataLoader, Dataset, decollate_batch
from monai.config import print_config
from monai.apps import download_and_extract
import torch
import matplotlib.pyplot as plt
import tempfile
import shutil
import os
import glob
import nrrd

print_config()
# Out:
# MONAI version: 1.2.0
# Numpy version: 1.24.3
# Pytorch version: 2.0.1+cu117
# MONAI flags: HAS_EXT = False, USE_COMPILED = False, USE_META_DICT = False
# MONAI rev id: c33f1ba588ee00229a309000e888f9817b4f1934
# MONAI __file__: /home/erattakulangara/.conda/envs/Pytorch/lib/python3.11/site-packages/monai/__init__.py
#
# Optional dependencies:
# Pytorch Ignite version: NOT INSTALLED or UNKNOWN VERSION.
# ITK version: 5.3.0
# Nibabel version: 5.1.0
# scikit-image version: 0.20.0
# Pillow version: 9.5.0
# Tensorboard version: NOT INSTALLED or UNKNOWN VERSION.
# gdown version: NOT INSTALLED or UNKNOWN VERSION.
# TorchVision version: 0.15.2+cu117
# tqdm version: 4.65.0
# lmdb version: NOT INSTALLED or UNKNOWN VERSION.
# psutil version: 5.9.5
# pandas version: 2.0.1
# einops version: NOT INSTALLED or UNKNOWN VERSION.
# transformers version: NOT INSTALLED or UNKNOWN VERSION.
# mlflow version: NOT INSTALLED or UNKNOWN VERSION.
# pynrrd version: 1.0.0
#
# For details about installing the optional dependencies, please visit:
#     https://docs.monai.io/en/latest/installation.html#installing-the-recommended-dependencies

# %%
directory = os.environ.get("DATA_DIRECTORY")
root_dir = './Train'
print(root_dir)
# Out:
# ./Train

# %%
train_images = sorted(
    glob.glob(os.path.join(root_dir, "RTrainVolumes", "*.nrrd")))
train_labels = sorted(
    glob.glob(os.path.join(root_dir, "RTrainLabels", "*.nrrd")))
data_dicts = [{"image": image_name, "label": label_name}
              for image_name, label_name in zip(train_images, train_labels)]
train_files, val_files = data_dicts[:-9], data_dicts[-9:]

# %%
print(data_dicts)
# Out:
# [{'image': './Train/RTrainVolumes/P10a.nrrd', 'label': './Train/RTrainLabels/P10a.seg.nrrd'}, {'image': './Train/RTrainVolumes/P10fi.nrrd', 'label': './Train/RTrainLabels/P10fi.seg.nrrd'}, {'image': './Train/RTrainVolumes/P10mi.nrrd', 'label': './Train/RTrainLabels/P10mi.seg.nrrd'}, {'image': './Train/RTrainVolumes/P10pa.nrrd', 'label': './Train/RTrainLabels/P10pa.seg.nrrd'}, {'image': './Train/RTrainVolumes/P10pi.nrrd', 'label': './Train/RTrainLabels/P10pi.seg.nrrd'}, {'image': './Train/RTrainVolumes/P10wa.nrrd', 'label': './Train/RTrainLabels/P10wa.seg.nrrd'}, {'image': './Train/RTrainVolumes/P1fi.nrrd', 'label': './Train/RTrainLabels/P1fi.seg.nrrd'}, {'image': './Train/RTrainVolumes/P1ma.nrrd', 'label': './Train/RTrainLabels/P1ma.seg.nrrd'}, {'image': './Train/RTrainVolumes/P1o.nrrd', 'label': './Train/RTrainLabels/P1o.seg.nrrd'}, {'image': './Train/RTrainVolumes/P1pa.nrrd', 'label': './Train/RTrainLabels/P1pa.seg.nrrd'}, {'image': './Train/RTrainVolumes/P1pu.nrrd', 'label': './Train/RTrainLabels/P1pu.seg.nrrd'}, {'image': './Train/RTrainVolumes/P1py.nrrd', 'label': './Train/RTrainLabels/P1py.seg.nrrd'}, {'image': './Train/RTrainVolumes/P1ren.nrrd', 'label': './Train/RTrainLabels/P1ren.seg.nrrd'}, {'image': './Train/RTrainVolumes/P1sa.nrrd', 'label': './Train/RTrainLabels/P1sa.seg.nrrd'}, {'image': './Train/RTrainVolumes/P1tu.nrrd', 'label': './Train/RTrainLabels/P1tu.seg.nrrd'}, {'image': './Train/RTrainVolumes/P2an.nrrd', 'label': './Train/RTrainLabels/P2an.seg.nrrd'}, {'image': './Train/RTrainVolumes/P2contact.nrrd', 'label': './Train/RTrainLabels/P2contact.seg.nrrd'}, {'image': './Train/RTrainVolumes/P2down.nrrd', 'label': './Train/RTrainLabels/P2down.seg.nrrd'}, {'image': './Train/RTrainVolumes/P2ka.nrrd', 'label': './Train/RTrainLabels/P2ka.seg.nrrd'}, {'image': './Train/RTrainVolumes/P2pa.nrrd', 'label': './Train/RTrainLabels/P2pa.seg.nrrd'}, {'image': './Train/RTrainVolumes/P2pi.nrrd', 'label': './Train/RTrainLabels/P2pi.seg.nrrd'}, {'image': './Train/RTrainVolumes/P2py.nrrd', 'label': './Train/RTrainLabels/P2py.seg.nrrd'}, {'image': './Train/RTrainVolumes/P2up.nrrd', 'label': './Train/RTrainLabels/P2up.seg.nrrd'}, {'image': './Train/RTrainVolumes/P2wa.nrrd', 'label': './Train/RTrainLabels/P2wa.seg.nrrd'}, {'image': './Train/RTrainVolumes/P2y.nrrd', 'label': './Train/RTrainLabels/P2y.seg.nrrd'}, {'image': './Train/RTrainVolumes/P7fa.nrrd', 'label': './Train/RTrainLabels/P7fa.seg.nrrd'}, {'image': './Train/RTrainVolumes/P7k2.nrrd', 'label': './Train/RTrainLabels/P7k2.seg.nrrd'}, {'image': './Train/RTrainVolumes/P7ka.nrrd', 'label': './Train/RTrainLabels/P7ka.seg.nrrd'}, {'image': './Train/RTrainVolumes/P7ko.nrrd', 'label': './Train/RTrainLabels/P7ko.seg.nrrd'}, {'image': './Train/RTrainVolumes/P7kon.nrrd', 'label': './Train/RTrainLabels/P7kon.seg.nrrd'}, {'image': './Train/RTrainVolumes/P7ku.nrrd', 'label': './Train/RTrainLabels/P7ku.seg.nrrd'}, {'image': './Train/RTrainVolumes/P7si.nrrd', 'label': './Train/RTrainLabels/P7si.seg.nrrd'}, {'image': './Train/RTrainVolumes/P7so.nrrd', 'label': './Train/RTrainLabels/P7so.seg.nrrd'}, {'image': './Train/RTrainVolumes/P7wa.nrrd', 'label': './Train/RTrainLabels/P7wa.seg.nrrd'}, {'image': './Train/RTrainVolumes/P8ki.nrrd', 'label': './Train/RTrainLabels/P8ki.seg.nrrd'}, {'image': './Train/RTrainVolumes/P8ko.nrrd', 'label': './Train/RTrainLabels/P8ko.seg.nrrd'}, {'image': './Train/RTrainVolumes/P8ku.nrrd', 'label': './Train/RTrainLabels/P8ku.seg.nrrd'}, {'image': './Train/RTrainVolumes/P8py.nrrd', 'label': './Train/RTrainLabels/P8py.seg.nrrd'}, {'image': './Train/RTrainVolumes/P9mi.nrrd', 'label': './Train/RTrainLabels/P9mi.seg.nrrd'}, {'image': './Train/RTrainVolumes/P9mon.nrrd', 'label': './Train/RTrainLabels/P9mon.seg.nrrd'}, {'image': './Train/RTrainVolumes/P9ri.nrrd', 'label': './Train/RTrainLabels/P9ri.seg.nrrd'}, {'image': './Train/RTrainVolumes/P9s2.nrrd', 'label': './Train/RTrainLabels/P9s2.seg.nrrd'}, {'image': './Train/RTrainVolumes/P9shE.nrrd', 'label': './Train/RTr ...

# %%
import nrrd
from monai.transforms import LoadImage
set_determinism(seed=0)

out = LoadImage(reader="NrrdReader")(
    "./Train/RTrainLabels/P10a.seg.nrrd")
out[0].shape
# Out:
# monai.transforms.io.array LoadImage.__init__:image_only: Current default value of argument `image_only=False` has been deprecated since version 1.1. It will be changed to `image_only=True` in version 1.3.
# torch.Size([32, 256, 256])

# %%
        # Lambdad(keys=['image', 'label'],
        #         func=lambda x: x[0:1]*0.2125 + x[1:2]*0.7154 + x[2:3]*0.0721),
train_transforms = Compose(
    [
        LoadImaged(keys=["image", "label"], reader="NrrdReader"),
        # Lambdad(keys=['image', 'label'],
        #          func=lambda x: x[0:1]*0.2125 + x[1:2]*0.7154 + x[2:3]*0.0721),
        EnsureChannelFirstd(keys=["image", "label"]),
        ScaleIntensityRanged(
            keys=["image"],
            a_min=-57,
            a_max=164,
            b_min=0.0,
            b_max=1.0,
            clip=True,
        ),
        CropForegroundd(keys=["image", "label"], source_key="image"),
        Orientationd(keys=["image", "label"], axcodes="RAS"),
        Spacingd(keys=["image", "label"], pixdim=(
            1.5, 1.5, 2.0), mode=("bilinear", "nearest")),
        RandCropByPosNegLabeld(
            keys=["image", "label"],
            label_key="label",
            spatial_size=(16, 96, 96),
            pos=1,
            neg=1,
            num_samples=4,
            image_key="image",
            image_threshold=0,
        ),
        # user can also add other random transforms
        # RandAffined(
        #     keys=['image', 'label'],
        #     mode=('bilinear', 'nearest'),
        #     prob=1.0, spatial_size=(96, 96, 96),
        #     rotate_range=(0, 0, np.pi/15),
        #     scale_range=(0.1, 0.1, 0.1)),
    ]
)
val_transforms = Compose(
    [
        LoadImaged(keys=["image", "label"], reader="NrrdReader"),
        EnsureChannelFirstd(keys=["image", "label"]),
        ScaleIntensityRanged(
            keys=["image"],
            a_min=-57,
            a_max=164,
            b_min=0.0,
            b_max=1.0,
            clip=True,
        ),
        CropForegroundd(keys=["image", "label"], source_key="image"),
        Orientationd(keys=["image", "label"], axcodes="RAS"),
        Spacingd(keys=["image", "label"], pixdim=(
            1.5, 1.5, 2.0), mode=("bilinear", "nearest")),
    ]
)
# Out:
# monai.transforms.io.dictionary LoadImaged.__init__:image_only: Current default value of argument `image_only=False` has been deprecated since version 1.1. It will be changed to `image_only=True` in version 1.3.

# %%
check_ds = Dataset(data=val_files, transform=train_transforms)
check_loader = DataLoader(check_ds, batch_size=1)
check_data = first(check_loader)
image, label = (check_data["image"], check_data["label"])
print(f"image shape: {image.shape}, label shape: {label.shape}")
# Out:
# image shape: torch.Size([4, 1, 16, 96, 96]), label shape: torch.Size([4, 1, 16, 96, 96])

# %%
check_ds = Dataset(data=val_files, transform=train_transforms)
check_loader = DataLoader(check_ds, batch_size=1)
check_data = first(check_loader)
image, label = (check_data["image"][0][0], check_data["label"][0][0])
print(f"image shape: {image.shape}, label shape: {label.shape}")
# plot the slice [:, :, 80]
plt.figure("check", (12, 6))
plt.subplot(1, 2, 1)
plt.title("image")
plt.imshow(image[:, :, 15], cmap="gray")
plt.subplot(1, 2, 2)
plt.title("label")
plt.imshow(label[:, :, 15])
plt.show()
# Out:
# image shape: torch.Size([16, 96, 96]), label shape: torch.Size([16, 96, 96])

# %%
train_ds = CacheDataset(
    data=train_files, transform=train_transforms, cache_rate=1.0, num_workers=4)
# train_ds = Dataset(data=train_files, transform=train_transforms)

# use batch_size=2 to load images and use RandCropByPosNegLabeld
# to generate 2 x 4 images for network training
train_loader = DataLoader(train_ds, batch_size=2, shuffle=True, num_workers=4)

val_ds = CacheDataset(
    data=val_files, transform=val_transforms, cache_rate=1.0, num_workers=4)
# val_ds = Dataset(data=val_files, transform=val_transforms)
val_loader = DataLoader(val_ds, batch_size=1, num_workers=4)
# Out:
# Loading dataset: 100%|██████████| 39/39 [00:02<00:00, 17.83it/s]
# Loading dataset: 100%|██████████| 9/9 [00:00<00:00, 12.71it/s]

# %%
# standard PyTorch program style: create UNet, DiceLoss and Adam optimizer
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

model = UNet(
    spatial_dims=3,
    in_channels=1,
    out_channels=1,
    channels=(16, 32, 64, 128, 256),
    strides=(2, 2, 2, 2),
    num_res_units=2,
    norm=Norm.BATCH,
).to(device)
loss_function = DiceLoss(to_onehot_y=True, softmax=True)
optimizer = torch.optim.Adam(model.parameters(), 1e-4)
dice_metric = DiceMetric(include_background=False, reduction="mean")

# %%
max_epochs = 6
val_interval = 2
best_metric = -1
best_metric_epoch = -1
epoch_loss_values = []
metric_values = []
post_pred = Compose([AsDiscrete(argmax=True)])
post_label = Compose([AsDiscrete()])

for epoch in range(max_epochs):
    print("-" * 10)
    print(f"epoch {epoch + 1}/{max_epochs}")
    model.train()
    epoch_loss = 0
    step = 0
    for batch_data in train_loader:
        step += 1
        inputs, labels = (
            batch_data["image"].to(device),
            batch_data["label"].to(device),
        )
        print(inputs.shape,labels.shape)
        optimizer.zero_grad()
        outputs = model(inputs)
        loss = loss_function(outputs, labels)
        loss.backward()
        optimizer.step()
        epoch_loss += loss.item()
        print(
            f"{step}/{len(train_ds) // train_loader.batch_size}, " f"train_loss: {loss.item():.4f}")
    epoch_loss /= step
    epoch_loss_values.append(epoch_loss)
    print(f"epoch {epoch + 1} average loss: {epoch_loss:.4f}")

    if (epoch + 1) % val_interval == 0:
        model.eval()
        with torch.no_grad():
            for val_data in val_loader:
                val_inputs, val_labels = (
                    val_data["image"].to(device),
                    val_data["label"].to(device),
                )
                roi_size = (32, 256, 256)
                sw_batch_size = 4
                val_outputs = sliding_window_inference(
                    val_inputs, roi_size, sw_batch_size, model)
                val_outputs = [post_pred(i)
                               for i in decollate_batch(val_outputs)]
                val_labels = [post_label(i)
                              for i in decollate_batch(val_labels)]
                # compute metric for current iteration
                dice_metric(y_pred=val_outputs, y=val_labels)

            # aggregate the final mean dice result
            metric = dice_metric.aggregate().item()
            # reset the status for next validation round
            dice_metric.reset()

            metric_values.append(metric)
            if metric > best_metric:
                best_metric = metric
                best_metric_epoch = epoch + 1
                torch.save(model.state_dict(), os.path.join(
                    root_dir, "best_metric_model.pth"))
                print("saved new best metric model")
            print(
                f"current epoch: {epoch + 1} current mean dice: {metric:.4f}"
                f"\nbest mean dice: {best_metric:.4f} "
                f"at epoch: {best_metric_epoch}"
            )
# Out:
# ----------
# epoch 1/6
# torch.Size([8, 1, 16, 96, 96]) torch.Size([8, 1, 16, 96, 96])
# single channel prediction, `softmax=True` ignored.
# single channel prediction, `to_onehot_y=True` ignored.
# 1/19, train_loss: 1.2121
# torch.Size([8, 1, 16, 96, 96]) torch.Size([8, 1, 16, 96, 96])
# 2/19, train_loss: 0.9636
# torch.Size([8, 1, 16, 96, 96]) torch.Size([8, 1, 16, 96, 96])
# 3/19, train_loss: 1.0747
# torch.Size([8, 1, 16, 96, 96]) torch.Size([8, 1, 16, 96, 96])
# 4/19, train_loss: 0.4964
# torch.Size([8, 1, 16, 96, 96]) torch.Size([8, 1, 16, 96, 96])
# 5/19, train_loss: 0.9431
# torch.Size([8, 1, 16, 96, 96]) torch.Size([8, 1, 16, 96, 96])
# 6/19, train_loss: 1.1304
# torch.Size([8, 1, 16, 96, 96]) torch.Size([8, 1, 16, 96, 96])
# 7/19, train_loss: 0.9341
# torch.Size([8, 1, 16, 96, 96]) torch.Size([8, 1, 16, 96, 96])
# 8/19, train_loss: 0.8460
# torch.Size([8, 1, 16, 96, 96]) torch.Size([8, 1, 16, 96, 96])
# 9/19, train_loss: 1.0288
# torch.Size([8, 1, 16, 96, 96]) torch.Size([8, 1, 16, 96, 96])
# 10/19, train_loss: 1.0101
# torch.Size([8, 1, 16, 96, 96]) torch.Size([8, 1, 16, 96, 96])
# 11/19, train_loss: 0.7174
# torch.Size([8, 1, 16, 96, 96]) torch.Size([8, 1, 16, 96, 96])
# 12/19, train_loss: 0.8738
# torch.Size([8, 1, 16, 96, 96]) torch.Size([8, 1, 16, 96, 96])
# 13/19, train_loss: 0.8808
# torch.Size([8, 1, 16, 96, 96]) torch.Size([8, 1, 16, 96, 96])
# 14/19, train_loss: 1.0107
# torch.Size([8, 1, 16, 96, 96]) torch.Size([8, 1, 16, 96, 96])
# 15/19, train_loss: 0.9032
# torch.Size([8, 1, 16, 96, 96]) torch.Size([8, 1, 16, 96, 96])
# 16/19, train_loss: 0.6340
# torch.Size([8, 1, 16, 96, 96]) torch.Size([8, 1, 16, 96, 96])
# 17/19, train_loss: -2.4243
# torch.Size([8, 1, 16, 96, 96]) torch.Size([8, 1, 16, 96, 96])
# 18/19, train_loss: 0.9248
# torch.Size([8, 1, 16, 96, 96]) torch.Size([8, 1, 16, 96, 96])
# 19/19, train_loss: 0.9576
# torch.Size([4, 1, 16, 96, 96]) torch.Size([4, 1, 16, 96, 96])
# 20/19, train_loss: 1.2627
# epoch 1 average loss: 0.7690
# ----------
# epoch 2/6
# torch.Size([8, 1, 16, 96, 96]) torch.Size([8, 1, 16, 96, 96])
# 1/19, train_loss: 0.8278
# torch.Size([8, 1, 16, 96, 96]) torch.Size([8, 1, 16, 96, 96])
# 2/19, train_loss: 1.0156
# torch.Size([8, 1, 16, 96, 96]) torch.Size([8, 1, 16, 96, 96])
# 3/19, train_loss: 0.9785
# torch.Size([8, 1, 16, 96, 96]) torch.Size([8, 1, 16, 96, 96])
# 4/19, train_loss: 1.0449
# torch.Size([8, 1, 16, 96, 96]) torch.Size([8, 1, 16, 96, 96])
# 5/19, train_loss: 0.5509
# torch.Size([8, 1, 16, 96, 96]) torch.Size([8, 1, 16, 96, 96])
# 6/19, train_loss: 0.8264
# torch.Size([8, 1, 16, 96, 96]) torch.Size([8, 1, 16, 96, 96])
# 7/19, train_loss: 0.7467
# torch.Size([8, 1, 16, 96, 96]) torch.Size([8, 1, 16, 96, 96])
# 8/19, train_loss: 0.8238
# torch.Size([8, 1, 16, 96, 96]) torch.Size([8, 1, 16, 96, 96])
# 9/19, train_loss: 1.0127
# torch.Size([8, 1, 16, 96, 96]) torch.Size([8, 1, 16, 96, 96])
# 10/19, train_loss: 0.9631
# torch.Size([8, 1, 16, 96, 96]) torch.Size([8, 1, 16, 96, 96])
# 11/19, train_loss: 0.8883
# torch.Size([8, 1, 16, 96, 96]) torch.Size([8, 1, 16, 96, 96])
# 12/19, train_loss: 0.8787
# torch.Size([8, 1, 16, 96, 96]) torch.Size([8, 1, 16, 96, 96])
# 13/19, train_loss: 0.8917
# torch.Size([8, 1, 16, 96, 96]) torch.Size([8, 1, 16, 96, 96])
# 14/19, train_loss: 1.0089
# torch.Size([8, 1, 16, 96, 96]) torch.Size([8, 1, 16, 96, 96])
# 15/19, train_loss: 16.9299
# torch.Size([8, 1, 16, 96, 96]) torch.Size([8, 1, 16, 96, 96])
# 16/19, train_loss: 1.0664
# torch.Size([8, 1, 16, 96, 96]) torch.Size([8, 1, 16, 96, 96])
# 17/19, train_loss: 0.8964
# torch.Size([8, 1, 16, 96, 96]) torch.Size([8, 1, 16, 96, 96])
# 18/19, train_loss: 0.9554
# torch.Size([8, 1, 16, 96, 96]) torch.Size([8, 1, 16, 96, 96])
# 19/19, train_loss: 1.0061
# torch.Size([4, 1, 16, 96, 96]) torch.Size([4, 1, 16, 96, 96])
# 20/19, train_loss: 0.9802
# epoch 2 average loss: 1.7146
# saved new best metric model
# current epoch: 2 current mean dice: 0.0000
# best mean dice: 0.0000 at epoch: 2
# ----------
# epoch 3/6
# torch.Size([8, 1, 16, 96, 96]) torch.Size([8, 1, 16, 96, 96])
# 1/19, train_loss: 0.8796
# torch.Size([8, 1, 16, 96, 96]) torch.Size([8, 1, 16, 96, 96])
# 2/19, train_loss: 1.7275
# torch.Size([8, 1, 16, 96, 96]) torch.Size([8, 1, 16, 96, 96])
# 3/19, train_loss: 0.9083
# torch.Size([8, 1, 16, 96, 96]) torch.Size([8, 1, 16, 96, 96])
# 4/19, train_loss: 0.9614
# torch.Size([8, 1, 16, 96, 96]) torch.Size([8, 1, 16, 96, 96])
# 5/19, train_loss: -0.4680
# torch.Size([8, 1, 16, 96, 96]) torch.Size([8, 1, 16, 96, 96])
# 6/19, train_loss: 0.9624
# torch.Size([8, 1, 16, 96, 96]) torch.Size([8, 1, 16, 96, 96])
# 7/19, train_loss: 0.8838
# torch.Size([8, 1, 16, 96, 96]) torch.Size([8, 1, 16, 96, 96])
# 8/19, train_loss: 1.2732
# torch.Size([8, 1, 16, 96, 96]) torch.Size([8, 1, 16, 96, 96])
# 9/19, train_loss: 0.9292
# torch.Size([8, 1, 16, 96, 96]) torch.Size([8, 1, 16, 96, 96])
# 10/19, train_loss: 0.7469
# torch.Size([8, 1, 16, 96, 96]) torch.Size([8, 1, 16, 96, 96])
# 11/19, train_loss: 1.7497
# torch.Size([8, 1, 16, 96, 96]) torch.Size([8, 1, 16, 96, 96])
# 12/19, train_loss: 1.0537
# torch.Size([8, 1, 16, 96, 96]) torch.Size([8, 1, 16, 96, 96])
# 13/19, train_loss: 0.9513
# torch.Size([8, 1, 16, 96, 96]) torch.Size([8, 1, 16, 96, 96])
# 14/19, train_loss: 0.8222
# torch.Size([8, 1, 16, 96, 96]) torch.Size([8, 1, 16, 96, 96])
# 15/19, train_loss: 1.0127
# torch.Size([8, 1, 16, 96, 96]) torch.Size([8, 1, 16, 96, 96])
# 16/19, train_loss: 0.5922
# torch.Size([8, 1, 16, 96, 96]) torch.Size([8, 1, 16, 96, 96])
# 17/19, train_loss: 22.9112
# torch.Size([8, 1, 16, 96, 96]) torch.Size([8, 1, 16, 96, 96])
# 18/19, train_loss: -0.6865
# torch.Size([8, 1, 16, 96, 96]) torch.Size([8, 1, 16, 96, 96])
# 19/19, train_loss: 0.7408
# torch.Size([4, 1, 16, 96, 96]) torch.Size([4, 1, 16, 96, 96])
# 20/19, train_loss: 0.8119
# epoch 3 average loss: 1.9382
# ----------
# epoch 4/6
# torch.Size([8, 1, 16, 96, 96]) torch.Size([8, 1, 16, 96, 96])
# 1/19, train_loss: 0.9433
# torch.Size([8, 1, 16, 96, 96]) torch.Size([8, 1, 16, 96, 96])
# 2/19, train_loss: 0.9723
# torch.Size([8, 1, 16, 96, 96]) torch.Size([8, 1, 16, 96, 96])
# 3/19, train_loss: 1.0891
# torch.Size([8, 1, 16, 96, 96]) torch.Size([8, 1, 16, 96, 96])
# 4/19, train_loss: 0.9973
# torch.Size([8, 1, 16, 96, 96]) torch.Size([8, 1, 16, 96, 96])
# 5/19, train_loss: 0.8661
# torch.Size([8, 1, 16, 96, 96]) torch.Size([8, 1, 16, 96, 96])
# 6/19, train_loss: 0.9512
# torch.Size([8, 1, 16, 96, 96]) torch.Size([8, 1, 16, 96, 96])
# 7/19, train_loss: 1.0135
# torch.Size([8, 1, 16, 96, 96]) torch.Size([8, 1, 16, 96, 96])
# 8/19, train_loss: 0.9467
# torch.Size([8, 1, 16, 96, 96]) torch.Size([8, 1, 16, 96, 96])
# 9/19, train_loss: 1.0628
# torch.Size([8, 1, 16, 96, 96]) torch.Size([8, 1, 16, 96, 96])
# 10/19, train_loss: 0.8707
# torch.Size([8, 1, 16, 96, 96]) torch.Size([8, 1, 16, 96, 96])
# 11/19, train_loss: 0.7161
# torch.Size([8, 1, 16, 96, 96]) torch.Size([8, 1, 16, 96, 96])
# 12/19, train_loss: 1.6908
# torch.Size([8, 1, 16, 96, 96]) torch.Size([8, 1, 16, 96, 96])
# 13/19, train_loss: -0.0879
# torch.Size([8, 1, 16, 96, 96]) torch.Size([8, 1, 16, 96, 96])
# 14/19, train_loss: 0.4619
# torch.Size([8, 1, 16, 96, 96]) torch.Size([8, 1, 16, 96, 96])
# 15/19, train_loss: 0.9608
# torch.Size([8, 1, 16, 96, 96]) torch.Size([8, 1, 16, 96, 96])
# 16/19, train_loss: 1.0205
# torch.Size([8, 1, 16, 96, 96]) torch.Size([8, 1, 16, 96, 96])
# 17/19, train_loss: 1.0970
# torch.Size([8, 1, 16, 96, 96]) torch.Size([8, 1, 16, 96, 96])
# 18/19, train_loss: 0.9541
# torch.Size([8, 1, 16, 96, 96]) torch.Size([8, 1, 16, 96, 96])
# 19/19, train_loss: 0.8133
# torch.Size([4, 1, 16, 96, 96]) torch.Size([4, 1, 16, 96, 96])
# 20/19, train_loss: 0.9455
# epoch 4 average loss: 0.9143
# current epoch: 4 current mean dice: 0.0000
# best mean dice: 0.0000 at epoch: 2
# ----------
# epoch 5/6
# torch.Size([8, 1, 16, 96, 96]) torch.Size([8, 1, 16, 96, 96])
# 1/19, train_loss: 1.8524
# torch.Size([8, 1, 16, 96, 96]) torch.Size([8, 1, 16, 96, 96])
# 2/19, train_loss: 1.6415
# torch.Size([8, 1, 16, 96, 96]) torch.Size([8, 1, 16, 96, 96])
# 3/19, train_loss: 1.0075
# torch.Size([8, 1, 16, 96, 96]) torch.Size([8, 1, 16, 96, 96])
# 4/19, train_loss: 0.9567
# torch.Size([8, 1, 16, 96, 96]) torch.Size([8, 1, 16, 96, 96])
# 5/19, train_loss: 0.5176
# torch.Size([8, 1, 16, 96, 96]) torch.Size([8, 1, 16, 96, 96])
# 6/19, train_loss: 0.9852
# torch.Size([8, 1, 16, 96, 96]) torch.Size([8, 1, 16, 96, 96])
# 7/19, train_loss: 0.8274
# torch.Size([8, 1, 16, 96, 96]) torch.Size([8, 1, 16, 96, 96])
# 8/19, train_loss: 4.1537
# torch.Size([8, 1, 16, 96, 96]) torch.Size([8, 1, 16, 96, 96])
# 9/19, train_loss: 1.0009
# torch.Size([8, 1, 16, 96, 96]) torch.Size([8, 1, 16, 96, 96])
# 10/19, train_loss: 0.8106
# torch.Size([8, 1, 16, 96, 96]) torch.Size([8, 1, 16, 96, 96])
# 11/19, train_loss: 0.9647
# torch.Size([8, 1, 16, 96, 96]) torch.Size([8, 1, 16, 96, 96])
# 12/19, train_loss: 1.0068
# torch.Size([8, 1, 16, 96, 96]) torch.Size([8, 1, 16, 96, 96])
# 13/19, train_loss: 0.9206
# torch.Size([8, 1, 16, 96, 96]) torch.Size([8, 1, 16, 96, 96])
# 14/19, train_loss: 0.9378
# torch.Size([8, 1, 16, 96, 96]) torch.Size([8, 1, 16, 96, 96])
# 15/19, train_loss: 1.0738
# torch.Size([8, 1, 16, 96, 96]) torch.Size([8, 1, 16, 96, 96])
# 16/19, train_loss: 0.8928
# torch.Size([8, 1, 16, 96, 96]) torch.Size([8, 1, 16, 96, 96])
# 17/19, train_loss: 0.9373
# torch.Size([8, 1, 16, 96, 96]) torch.Size([8, 1, 16, 96, 96])
# 18/19, train_loss: 0.9037
# torch.Size([8, 1, 16, 96, 96]) torch.Size([8, 1, 16, 96, 96])
# 19/19, train_loss: 1.0322
# torch.Size([4, 1, 16, 96, 96]) torch.Size([4, 1, 16, 96, 96])
# 20/19, train_loss: 0.9282
# epoch 5 average loss: 1.1676
# ----------
# epoch 6/6
# torch.Size([8, 1, 16, 96, 96]) torch.Size([8, 1, 16, 96, 96])
# 1/19, train_loss: 0.8007
# torch.Size([8, 1, 16, 96, 96]) torch.Size([8, 1, 16, 96, 96])
# 2/19, train_loss: 0.8500
# torch.Size([8, 1, 16, 96, 96]) torch.Size([8, 1, 16, 96, 96])
# 3/19, train_loss: 1.8371
# torch.Size([8, 1, 16, 96, 96]) torch.Size([8, 1, 16, 96, 96])
# 4/19, train_loss: 0.5528
# torch.Size([8, 1, 16, 96, 96]) torch.Size([8, 1, 16, 96, 96])
# 5/19, train_loss: 0.4168
# torch.Size([8, 1, 16, 96, 96]) torch.Size([8, 1, 16, 96, 96])
# 6/19, train_loss: 1.0544
# torch.Size([8, 1, 16, 96, 96]) torch.Size([8, 1, 16, 96, 96])
# 7/19, train_loss: 0.9578
# torch.Size([8, 1, 16, 96, 96]) torch.Size([8, 1, 16, 96, 96])
# 8/19, train_loss: 0.9955
# torch.Size([8, 1, 16, 96, 96]) torch.Size([8, 1, 16, 96, 96])
# 9/19, train_loss: 0.9351
# torch.Size([8, 1, 16, 96, 96]) torch.Size([8, 1, 16, 96, 96])
# 10/19, train_loss: 0.5615
# torch.Size([8, 1, 16, 96, 96]) torch.Size([8, 1, 16, 96, 96])
# 11/19, train_loss: 0.7027
# torch.Size([8, 1, 16, 96, 96]) torch.Size([8, 1, 16, 96, 96])
# 12/19, train_loss: 0.9898
# torch.Size([8, 1, 16, 96, 96]) torch.Size([8, 1, 16, 96, 96])
# 13/19, train_loss: 0.7137
# torch.Size([8, 1, 16, 96, 96]) torch.Size([8, 1, 16, 96, 96])
# 14/19, train_loss: 1.0104
# torch.Size([8, 1, 16, 96, 96]) torch.Size([8, 1, 16, 96, 96])
# 15/19, train_loss: 0.8505
# torch.Size([8, 1, 16, 96, 96]) torch.Size([8, 1, 16, 96, 96])
# 16/19, train_loss: 0.9743
# torch.Size([8, 1, 16, 96, 96]) torch.Size([8, 1, 16, 96, 96])
# 17/19, train_loss: 1.3613
# torch.Size([8, 1, 16, 96, 96]) torch.Size([8, 1, 16, 96, 96])
# 18/19, train_loss: 0.7655
# torch.Size([8, 1, 16, 96, 96]) torch.Size([8, 1, 16, 96, 96])
# 19/19, train_loss: 1.0952
# torch.Size([4, 1, 16, 96, 96]) torch.Size([4, 1, 16, 96, 96])
# 20/19, train_loss: 0.7783
# epoch 6 average loss: 0.9102
# current epoch: 6 current mean dice: 0.0000
# best mean dice: 0.0000 at epoch: 2

# %%
print(f"train completed, best_metric: {best_metric:.4f} " f"at epoch: {best_metric_epoch}")
# Out:
# train completed, best_metric: 0.0000 at epoch: 2

# %%
plt.figure("train", (12, 6))
plt.subplot(1, 2, 1)
plt.title("Epoch Average Loss")
x = [i + 1 for i in range(len(epoch_loss_values))]
y = epoch_loss_values
plt.xlabel("epoch")
plt.plot(x, y)
plt.subplot(1, 2, 2)
plt.title("Val Mean Dice")
x = [val_interval * (i + 1) for i in range(len(metric_values))]
y = metric_values
plt.xlabel("epoch")
plt.plot(x, y)
plt.show()

# %%
model.load_state_dict(torch.load(
    os.path.join(root_dir, "best_metric_model.pth")))
model.eval()
with torch.no_grad():
    for i, val_data in enumerate(val_loader):
        roi_size = (160, 160, 160)
        sw_batch_size = 4
        val_outputs = sliding_window_inference(
            val_data["image"].to(device), roi_size, sw_batch_size, model)
        # plot the slice [:, :, 80]
        plt.figure("check", (18, 6))
        plt.subplot(1, 3, 1)
        plt.title(f"image {i}")
        plt.imshow(val_data["image"][0, 0, :, :, 80], cmap="gray")
        plt.subplot(1, 3, 2)
        plt.title(f"label {i}")
        plt.imshow(val_data["label"][0, 0, :, :, 80])
        plt.subplot(1, 3, 3)
        plt.title(f"output {i}")
        plt.imshow(torch.argmax(
            val_outputs, dim=1).detach().cpu()[0, :, :, 80])
        plt.show()
        if i == 2:
            break
